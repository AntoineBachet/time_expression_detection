# %% [markdown]
# ### Import Libraries

# %%
from collections import OrderedDict
import torch
import numpy as np
import dill as pickle
from collections import Counter

# %%
import sys
sys.path.append("sopa_master")

# %%
from data import read_embeddings, read_docs, read_labels
from soft_patterns import ProbSemiring, MaxPlusSemiring, LogSpaceMaxTimesSemiring, SoftPatternClassifier, train, Batch, evaluate_accuracy
from util import to_cuda
from interpret_classification_results import interpret_documents
from visualize import visualize_patterns as vp

# %% [markdown]
# ### Load Files

# %%
test_file = "data/time_data_clean/test.data"
test_label_file = "data/time_data_clean/test.labels"

# %%
patterns = "7-10_6-10_5-10_4-10_3-10_2-10"
pattern_specs = OrderedDict(sorted(([int(y) for y in x.split("-")] for x in patterns.split("_")),
                                key=lambda t: t[0]))

# %%
vocab = pickle.load(open("data/embeddings/vocab.p","rb"))
embeddings = pickle.load(open("data/embeddings/embeddings.p","rb"))
word_dim = pickle.load(open("data/embeddings/word_dim.p","rb"))

# %% [markdown]
# ### Create Model

# %%
model = SoftPatternClassifier(
    pattern_specs=pattern_specs,
    mlp_hidden_dim=25,
    num_mlp_layers=5,
    num_classes=2,
    embeddings=embeddings,
    vocab=vocab,
    semiring=LogSpaceMaxTimesSemiring,
    bias_scale_param=0.1,
    shared_sl=False,
    no_sl=False
)
# Out:
# 60 OrderedDict([(2, 10), (3, 10), (4, 10), (5, 10), (6, 10), (7, 10)])
# # params: 256727

# %% [markdown]
# ### Load weights

# %%
model_dict = torch.load("data/models/best_sopa.pth")
model.load_state_dict(model_dict)

# %% [markdown]
# ### Load test data

# %%
test_input, test_text = read_docs(test_file, vocab, num_padding_tokens=0)

# %%
test_labels = read_labels(test_label_file)
test_data = list(zip(test_input, test_labels))

# %%
evaluate_accuracy(model, test_data, batch_size=150, gpu=False)
# Out:
# num predicted 1s: 212
# num gold 1s:      232
# 0.9394773039889959

# %%
vp(model, test_data[:100], test_text[:100], k_best=5, max_doc_len=-1, num_padding_tokens=0)
# Out:
# .Pattern: 0 of length 2
# Highest scoring spans:
# 0 -0.290  b'HP now            #label=1'
# 1 -0.290  b'HP now            #label=1'
# 2 -0.337  b'HP today          #label=1'
# 3 -0.349  b'HP 1988           #label=1'
# 4 -0.357  b'HP todays         #label=1'
# self-loops:   1.00 * carefree        + -0.29,  1.00 * bOy             +  0.38
# fwd 1s:       5.49 * 18:01:12        +  1.20
# epsilons:                              -1.59
#
# Pattern: 1 of length 2
# Highest scoring spans:
# 0 -0.211  b'HP Friday,        #label=1'
# 1 -0.211  b'HP Friday,        #label=1'
# 2 -0.224  b'HP today          #label=1'
# 3 -0.233  b'HP Friday         #label=1'
# 4 -0.233  b'HP Friday         #label=1'
# self-loops:   1.00 * THEA            +  0.60,  1.00 * Strella         +  0.11
# fwd 1s:       5.59 * May-25-2013     + -0.47
# epsilons:                              -2.35
#
# Pattern: 2 of length 2
# Highest scoring spans:
# 0 -0.309  b'HP agree          #label=0'
# 1 -0.327  b'HP abortion       #label=0'
# 2 -0.327  b'HP abortion       #label=1'
# 3 -0.339  b'HP comment        #label=0'
# 4 -0.349  b'HP case           #label=1'
# self-loops:   1.00 * bilabial        + -1.44,  4.49 * 877             + -1.27
# fwd 1s:       4.11 * disagree        + -1.49
# epsilons:                              -0.14
#
# Pattern: 3 of length 2
# Highest scoring spans:
# 0 -0.266  b'HP Friday,        #label=1'
# 1 -0.266  b'HP Friday,        #label=1'
# 2 -0.307  b'HP today          #label=1'
# 3 -0.329  b'HP Thursday       #label=1'
# 4 -0.333  b'HP Friday         #label=1'
# self-loops:   1.00 * gigabyte        + -1.54,  1.00 * Calpurnia       + -0.73
# fwd 1s:       5.33 * vehicle.Receive +  0.45
# epsilons:                              -0.64
#
# Pattern: 4 of length 2
# Highest scoring spans:
# 0 -0.154  b'HP Friday         #label=1'
# 1 -0.154  b'HP Friday         #label=1'
# 2 -0.154  b'HP Friday         #label=1'
# 3 -0.161  b'HP Thursday       #label=1'
# 4 -0.166  b'HP Tuesday        #label=1'
# self-loops:   1.00 * Commerciales    +  0.38,  1.00 * 47.42000        + -1.77
# fwd 1s:       5.44 * Feburary        + -0.67
# epsilons:                              -0.45
#
# Pattern: 5 of length 2
# Highest scoring spans:
# 0 -0.230  b'HP Friday,        #label=1'
# 1 -0.230  b'HP Friday,        #label=1'
# 2 -0.257  b'HP brainwash      #label=0'
# 3 -0.289  b'HP 1992           #label=1'
# 4 -0.292  b'HP 1956           #label=1'
# self-loops:   1.00 * MCMLXXXVIII     + -0.77,  1.00 * 16.98           +  0.27
# fwd 1s:       5.59 * 21:23:20        +  1.36
# epsilons:                              -0.07
#
# Pattern: 6 of length 2
# Highest scoring spans:
# 0 -0.286  b'HP today          #label=1'
# 1 -0.303  b'HP now            #label=1'
# 2 -0.303  b'HP now            #label=1'
# 3 -0.340  b'HP here           #label=0'
# 4 -0.340  b'HP you,           #label=0'
# self-loops:   1.00 * link.InboxerBiz + -1.07,  1.00 * Purcell         + -0.54
# fwd 1s:       5.03 * itunes.apple.com +  0.86
# epsilons:                              -0.94
#
# Pattern: 7 of length 2
# Highest scoring spans:
# 0 -0.346  b'HP Gonzalez       #label=0'
# 1 -0.356  b'HP Kopp           #label=0'
# 2 -0.356  b'HP Kopp           #label=1'
# 3 -0.391  b'HP Juanita        #label=0'
# 4 -0.404  b'HP enabled        #label=0'
# self-loops:   1.00 * size10          + -1.90,  1.00 * Propeller       +  0.95
# fwd 1s:       4.38 * Pwint           +  0.01
# epsilons:                              -0.76
#
# Pattern: 8 of length 2
# Highest scoring spans:
# 0 -0.371  b'HP you,           #label=0'
# 1 -0.385  b'HP Rallys         #label=0'
# 2 -0.385  b'HP Eileen         #label=0'
# 3 -0.386  b'HP celebrations   #label=1'
# 4 -0.405  b'HP eastward       #label=0'
# self-loops:   1.00 * chain           + -0.36,  1.00 * Placesany       +  0.40
# fwd 1s:       3.53 * South-southeastFinal +  1.59
# epsilons:                              -0.93
#
# Pattern: 9 of length 2
# Highest scoring spans:
# 0 -0.319  b'HP today          #label=1'
# 1 -0.324  b'HP Friday,        #label=1'
# 2 -0.324  b'HP Friday,        #label=1'
# 3 -0.331  b'HP now            #label=1'
# 4 -0.331  b'HP now            #label=1'
# self-loops:   1.00 * law             + -0.95,  1.00 * remove/delete   +  0.42
# fwd 1s:       4.83 * 10:18:04        +  0.21
# epsilons:                              -0.29
#
# Pattern: 10 of length 3
# Highest scoring spans:
# 0 -0.776  b'ep                HP Kopp           #label=0'
# 1 -0.776  b'ep                HP Kopp           #label=1'
# 2 -0.786  b'ep                HP Gonzalez       #label=0'
# 3 -0.788  b'ep                HP greatgrandfather#label=0'
# 4 -0.790  b'ep                HP case           #label=1'
# self-loops:   1.00 * Barry           + -0.58,  1.00 * Bissell         +  0.01,  1.00 * MERIBEL         + -0.65
# fwd 1s:       1.00 * Colicchio       +  0.34,  4.18 * Parratt         +  0.58
# epsilons:                              -0.41,                           -1.73
#
# Pattern: 11 of length 3
# Highest scoring spans:
# 0 -0.797  b'HP instead        HP if             #label=0'
# 1 -0.799  b'HP in             HP good           #label=0'
# 2 -0.814  b'HP not            HP saying         #label=0'
# 3 -0.828  b'HP 5              HP 1/2            #label=1'
# 4 -0.842  b'HP very           HP different      #label=0'
# self-loops:   1.00 * Musu            + -1.39,  1.00 * PredsOnTheGlass +  0.13,  1.00 * Mgm             +  0.85
# fwd 1s:       3.38 * at              + -0.09,  4.13 * disagree        + -0.05
# epsilons:                              -0.77,                           -1.01
#
# Pattern: 12 of length 3
# Highest scoring spans:
# 0 -0.634  b'HP approval       HP and            #label=1'
# 1 -0.698  b'HP stock          HP and            #label=0'
# 2 -0.700  b'HP compete        HP and            #label=0'
# 3 -0.779  b'HP business       HP and            #label=0'
# 4 -0.807  b'HP should         HP help           #label=0'
# self-loops:   1.00 * content         + -1.82,  3.32 * navigatie       +  1.95,  1.00 * Lyndall         + -0.54
# fwd 1s:       4.77 * dayShipping     +  0.75,  3.57 * and             +  0.31
# epsilons:                              -1.09,                           -1.25
#
# Pattern: 13 of length 3
# Highest scoring spans:
# 0 -1.039  b'ep                HP fire           #label=0'
# 1 -1.065  b'ep                HP The            #label=1'
# 2 -1.065  b'ep                HP The            #label=0'
# 3 -1.065  b'ep                HP The            #label=1'
# 4 -1.065  b'ep                HP The            #label=1'
# self-loops:   1.00 * 2:09:02         +  1.74,  1.00 * bupropion       + -0.00,  1.00 * 2.550           + -0.01
# fwd 1s:       1.00 * NavigationStudentsE-NetFaculty + -0.91,  4.12 * AwayThe         + -0.08
# epsilons:                              -0.71,                           -0.41
#
# Pattern: 14 of length 3
# Highest scoring spans:
# 0 -1.116  b'HP remembers      HP the            #label=1'
# 1 -1.120  b'HP Smith          HP of             #label=0'
# 2 -1.126  b'HP holding        HP company        #label=1'
# 3 -1.128  b'HP Friday,        HP Conseco        #label=1'
# 4 -1.130  b'HP highprofile    HP product,       #label=0'
# self-loops:   1.00 * STEVENS         + -0.03,  1.00 * tone-only       + -0.24,  3.98 * ep.This         +  0.41
# fwd 1s:       4.47 * Deskripsi       +  1.81,  1.00 * Nihilanth       + -0.66
# epsilons:                              -0.65,                           -0.28
#
# Pattern: 15 of length 3
# Highest scoring spans:
# 0 -0.425  b'HP Friday         HP Oct            #label=1'
# 1 -0.556  b'HP on             HP Tuesday        #label=1'
# 2 -0.560  b'HP on             HP Friday         #label=1'
# 3 -0.560  b'HP on             HP Friday         #label=1'
# 4 -0.641  b'HP the            HP farright       #label=1'
# self-loops:   1.00 * ScentSationals  + -0.17,  1.00 * Coolflo         +  0.39,  1.00 * PSI             + -0.43
# fwd 1s:       5.64 * Thurday         +  0.32,  5.58 * 20:42:17        +  0.49
# epsilons:                              -0.76,                           -1.46
#
# Pattern: 16 of length 3
# Highest scoring spans:
# 0 -1.125  b'ep                HP very           #label=0'
# 1 -1.125  b'ep                HP very           #label=0'
# 2 -1.125  b'ep                HP very           #label=0'
# 3 -1.129  b'ep                HP good           #label=0'
# 4 -1.154  b'ep                HP extremely      #label=0'
# self-loops:   1.00 * 65K-color       +  0.84,  1.00 * Evalyn          +  0.24,  1.00 * Kerosin         +  0.24
# fwd 1s:       1.00 * Bennahum        + -1.00,  2.89 * Vocals          + -0.84
# epsilons:                              -0.65,                           -0.45
#
# Pattern: 17 of length 3
# Highest scoring spans:
# 0 -0.742  b'HP hours          HP on             #label=1'
# 1 -0.808  b'HP everyday       HP matter         #label=0'
# 2 -0.827  b'HP the            HP suit           #label=0'
# 3 -0.831  b'HP in             HP good           #label=0'
# 4 -0.842  b'HP in             HP custody        #label=1'
# self-loops:   1.00 * Yelick          +  0.58,  1.00 * Dripping        + -0.66,  1.00 * Split-Screen    + -0.89
# fwd 1s:       3.08 * lasts           +  1.18,  4.26 * evidentiary     +  1.29
# epsilons:                              -0.60,                           -1.89
#
# Pattern: 18 of length 3
# Highest scoring spans:
# 0 -1.109  b'HP Ive            HP been           #label=0'
# 1 -1.115  b'HP hes            HP better         #label=0'
# 2 -1.120  b'HP hes            HP out            #label=0'
# 3 -1.123  b'HP Rallys         HP founder        #label=0'
# 4 -1.149  b'HP good           HP will           #label=0'
# self-loops:   1.00 * MK992           +  1.72,  1.00 * fastdetect      +  0.03,  4.43 * Salkin          +  0.15
# fwd 1s:       4.79 * fortable        + -0.90,  1.00 * Chairman-in-Office + -1.66
# epsilons:                              -0.96,                           -0.63
#
# Pattern: 19 of length 3
# Highest scoring spans:
# 0 -0.824  b'ep                HP 0              #label=0'
# 1 -0.837  b'ep                HP U              #label=0'
# 2 -0.837  b'ep                HP U              #label=1'
# 3 -0.844  b'ep                HP Rallys         #label=0'
# 4 -0.857  b'ep                HP Ive            #label=0'
# self-loops:   1.00 * 4em             +  0.25,  1.00 * prevalency      + -0.43,  1.00 * andyg           +  0.98
# fwd 1s:       1.00 * Hang            + -1.76,  3.64 * show_portrait   +  0.51
# epsilons:                              -0.47,                           -1.09
#
# Pattern: 20 of length 4
# Highest scoring spans:
# 0 -1.537  b'ep                HP snipers        HP bullet         #label=1'
# 1 -1.619  b'ep                HP Nazi           HP SS             #label=0'
# 2 -1.659  b'HP told,          ep                HP shes           #label=0'
# 3 -1.661  b'ep                HP bomb           HP landed         #label=0'
# 4 -1.699  b'ep                HP whats          HP happening      #label=0'
# self-loops:   1.00 * LSGH            + -0.90,  1.00 * inundated       + -1.04,  2.24 * waistline.More  +  1.26,  1.00 * GTK3            + -0.65
# fwd 1s:       1.26 * @require        + -0.69,  4.69 * Parratt         + -0.14,  4.59 * on-brand        +  0.50
# epsilons:                              -0.71,                           -0.63,                           -1.03
#
# Pattern: 21 of length 4
# Highest scoring spans:
# 0 -1.259  b'ep                HP enabled        HP Mr             #label=0'
# 1 -1.382  b'HP thrift         HP holding        HP company        #label=1'
# 2 -1.399  b'HP A              HP district       HP court          #label=0'
# 3 -1.433  b'ep                HP organization   HP said           #label=1'
# 4 -1.456  b'ep                HP entity         HP 55             #label=0'
# self-loops:   1.00 * LHGA            +  0.31,  1.00 * Koshansky       + -0.56,  1.00 * cathys          +  0.58,  1.00 * 1-248           + -1.76
# fwd 1s:       4.05 * liningwhen      +  1.36,  4.01 * Amosun          +  0.19,  4.18 * factually       +  0.48
# epsilons:                              -0.55,                           -1.25,                           -1.43
#
# Pattern: 22 of length 4
# Highest scoring spans:
# 0 -1.161  b'HP last           HP week           HP that           #label=1'
# 1 -1.306  b'HP todays         HP youth          HP what           #label=1'
# 2 -1.327  b'HP last           HP month          HP that           #label=1'
# 3 -1.349  b'HP 1992           HP it             HP intended       #label=1'
# 4 -1.379  b'HP states         HP since          HP 1990           #label=1'
# self-loops:   1.00 * 19475           + -2.03,  2.94 * Meana           +  1.34,  1.00 * b.Mar           + -0.45,  1.00 * Optics          +  0.37
# fwd 1s:       5.74 * previous        + -0.18,  5.15 * incidentsAccess +  0.57,  5.00 * Topics20        +  0.94
# epsilons:                              -1.05,                           -0.83,                           -1.30
#
# Pattern: 23 of length 4
# Highest scoring spans:
# 0 -0.936  b'HP through        HP next           HP year           #label=1'
# 1 -0.999  b'HP Sunday         HP in             HP a              #label=1'
# 2 -1.000  b'HP week           HP or             HP so             #label=1'
# 3 -1.014  b'HP scheduled      HP to             HP spend          #label=1'
# 4 -1.118  b'HP million        HP a              HP year           #label=0'
# self-loops:   1.00 * Sea-Tac         +  0.01,  1.00 * gameshow        +  0.10,  1.94 * NiGHT           +  0.97,  1.00 * DOSSIER         + -0.03
# fwd 1s:       5.58 * tomorrow        + -0.06,  4.75 * second-straight +  0.40,  5.22 * ago.I           +  0.95
# epsilons:                              -1.07,                           -1.29,                           -0.64
#
# Pattern: 24 of length 4
# Highest scoring spans:
# 0 -1.032  b'ep                HP Saturday       HP vowed          #label=1'
# 1 -1.157  b'ep                HP Friday         HP Oct            #label=1'
# 2 -1.159  b'ep                HP last           HP week           #label=1'
# 3 -1.291  b'ep                HP on             HP Friday         #label=1'
# 4 -1.291  b'ep                HP on             HP Friday         #label=1'
# self-loops:   1.00 * Thesaurus.Change + -0.67,  1.00 * Mardou          + -0.49,  1.00 * Weaner          + -1.35,  1.00 * scandal?YesNoUndecidedOtherLogin + -1.05
# fwd 1s:       1.00 * PreActivated    + -0.15,  5.36 * Friday          + -0.52,  4.99 * Fatorda         +  0.47
# epsilons:                              -0.54,                           -1.03,                           -0.94
#
# Pattern: 25 of length 4
# Highest scoring spans:
# 0 -1.412  b'HP in             HP charge         HP of             #label=0'
# 1 -1.452  b'HP a              HP number         HP of             #label=1'
# 2 -1.454  b'HP of             HP Jordans        HP long           #label=0'
# 3 -1.483  b'HP in             HP north          HP Carolina       #label=0'
# 4 -1.505  b'HP are            HP not            HP helping        #label=0'
# self-loops:   1.00 * self-tests      +  1.18,  1.00 * for7            +  0.59,  3.04 * invasion        +  0.58,  1.66 * HEFFNER         + -0.71
# fwd 1s:       4.87 * Insabina        +  1.13,  4.87 * boo-quets       + -0.33,  3.86 * Eight80         + -0.82
# epsilons:                              -1.27,                           -1.59,                           -0.58
#
# Pattern: 26 of length 4
# Highest scoring spans:
# 0 -0.757  b'HP the            ep                HP bombing        #label=1'
# 1 -0.762  b'HP a              ep                HP snipers        #label=1'
# 2 -0.787  b'HP the            ep                HP repatriation   #label=0'
# 3 -0.806  b'HP the            ep                HP bombings       #label=1'
# 4 -0.847  b'HP The            ep                HP INS            #label=1'
# self-loops:   1.00 * life.More       + -0.41,  3.93 * companys        +  1.21,  1.00 * Falloden        +  0.30,  1.00 * Jumon           + -0.45
# fwd 1s:       3.71 * A               + -0.01,  1.00 * Zather          + -0.37,  5.18 * airliner        + -1.14
# epsilons:                              -0.73,                           -0.23,                           -0.41
#
# Pattern: 27 of length 4
# Highest scoring spans:
# 0 -1.146  b'HP cents          HP on             HP Friday         #label=1'
# 1 -1.162  b'HP conference     HP on             HP Tuesday        #label=1'
# 2 -1.176  b'HP NATO           HP on             HP Friday         #label=1'
# 3 -1.188  b'HP explosives     ep                HP Sunday         #label=1'
# 4 -1.197  b'HP trading        ep                HP Friday,        #label=1'
# self-loops:   1.00 * Peebles         +  1.20,  1.00 * Vorden          + -0.28,  1.56 * grown.Less      +  0.35,  1.91 * 18/09/10        + -0.09
# fwd 1s:       1.00 * douce           + -2.17,  5.90 * monthActivity   + -0.03,  6.00 * ,10:00          +  0.16
# epsilons:                              -0.86,                           -0.26,                           -0.26
#
# Pattern: 28 of length 4
# Highest scoring spans:
# 0 -1.554  b'HP Schwarzs       HP greatgrandfatherHP founded        #label=0'
# 1 -1.561  b'HP the            HP companys       HP U              #label=0'
# 2 -1.581  b'ep                HP Sansui         HP was            #label=0'
# 3 -1.678  b'HP bombing,       HP Satcher        HP said           #label=0'
# 4 -1.683  b'HP with           HP Rallys         HP founder        #label=0'
# self-loops:   1.00 * mutilate        +  0.65,  1.00 * Bentley         +  1.06,  1.00 * #hp             + -0.16,  1.00 * featureadded    + -0.49
# fwd 1s:       1.00 * reviewStar      + -1.23,  5.38 * fornt           + -0.28,  4.63 * Hes             +  0.05
# epsilons:                              -0.82,                           -1.04,                           -0.84
#
# Pattern: 29 of length 4
# Highest scoring spans:
# 0 -1.243  b'HP capital        HP will           HP be             #label=0'
# 1 -1.270  b'HP said           HP at             HP a              #label=0'
# 2 -1.361  b'HP transaction    HP costs          HP from           #label=1'
# 3 -1.367  b'HP reported       HP range          HP of             #label=0'
# 4 -1.389  b'HP securities     HP portfolio      HP of             #label=0'
# self-loops:   1.00 * Two-Die         + -0.54,  1.00 * EICTA           + -0.70,  1.00 * duplicating     + -0.01,  1.00 * 34473           + -0.96
# fwd 1s:       4.48 * acquisition     + -0.77,  4.14 * reccommend      +  0.17,  4.31 * lier            +  1.14
# epsilons:                              -1.22,                           -1.16,                           -0.47
#
# Pattern: 30 of length 5
# Highest scoring spans:
# 0 -1.415  b'ep                HP It             ep                HP hasnt          #label=0'
# 1 -1.513  b'ep                HP He             ep                HP wont           #label=0'
# 2 -1.538  b'HP economies      HP is             ep                HP also           #label=0'
# 3 -1.597  b'ep                HP He             ep                HP also           #label=1'
# 4 -1.601  b'ep                HP An             ep                HP elderly        #label=0'
# self-loops:   1.00 * Single-Season   + -0.77,  1.00 * Lippstadt       + -0.40,  5.20 * protrudes       +  1.97,  1.00 * filmiki         +  0.15,  1.00 * 22.79           + -0.23
# fwd 1s:       4.37 * equities        + -0.45,  4.17 * Always          + -0.41,  4.42 * grandparent     +  0.73,  3.69 * allways         + -1.25
# epsilons:                              -0.43,                           -0.42,                           -0.32,                           -1.45
#
# Pattern: 31 of length 5
# Highest scoring spans:
# 0 -1.459  b'HP last           HP week           ep                HP that           #label=1'
# 1 -1.548  b'HP time           HP four           HP of             HP six            #label=0'
# 2 -1.564  b'HP last           HP month          ep                HP that           #label=1'
# 3 -1.677  b'HP 1956           HP uprising       HP as             HP a              #label=1'
# 4 -1.693  b'HP the            HP slaying        HP of             HP a              #label=1'
# self-loops:   1.00 * 10000RPM        +  0.84,  1.00 * 3.75            + -1.08,  1.49 * Acie            +  0.42,  1.00 * hoards          + -1.08,  1.00 * completing      + -0.03
# fwd 1s:       5.45 * last            + -0.36,  4.80 * OOTD            +  0.51,  5.25 * need10          +  1.26,  5.12 * telephoned      +  0.55
# epsilons:                              -1.18,                           -0.80,                           -0.67,                           -0.72
#
# Pattern: 32 of length 5
# Highest scoring spans:
# 0 -1.683  b'ep                HP is             HP executive      HP vice           #label=0'
# 1 -1.752  b'ep                HP is             HP redeeming      HP the            #label=0'
# 2 -1.786  b'ep                HP are            HP not            HP at             #label=0'
# 3 -1.831  b'ep                HP dont           HP know           HP what           #label=0'
# 4 -1.877  b'ep                HP not            HP appear         HP that           #label=0'
# self-loops:   1.00 * moreWorld       +  1.07,  1.00 * cradle          + -0.89,  1.00 * Max-Viz         + -0.20,  1.00 * 29253           +  0.52,  1.00 * ITNG            + -0.92
# fwd 1s:       1.00 * post.To         + -1.34,  4.55 * usally          +  0.51,  4.26 * 2ndairyfurmentashn +  0.43,  3.76 * and             +  1.07
# epsilons:                              -0.61,                           -0.33,                           -1.24,                           -0.26
#
# Pattern: 33 of length 5
# Highest scoring spans:
# 0 -1.005  b'ep                HP explosives     HP Sunday         HP in             #label=1'
# 1 -1.107  b'ep                HP murder         HP Thursday       HP in             #label=1'
# 2 -1.131  b'ep                HP a              HP year           HP in             #label=0'
# 3 -1.205  b'ep                HP bomb           HP landed         HP in             #label=0'
# 4 -1.298  b'ep                HP 1/2            HP hours          HP in             #label=1'
# self-loops:   1.00 * Spandex         +  0.64,  1.00 * 20:11           +  0.58,  1.00 * Espoir          + -0.31,  3.97 * denationalized  +  0.77,  1.00 * Flora2000       + -2.21
# fwd 1s:       1.00 * Gibbethon       + -1.21,  5.75 * alleges         +  1.06,  6.38 * week            + -0.42,  5.68 * in              + -1.07
# epsilons:                              -0.50,                           -1.07,                           -1.54,                           -0.24
#
# Pattern: 34 of length 5
# Highest scoring spans:
# 0 -1.832  b'ep                HP regulatory     HP approval       HP and            #label=1'
# 1 -1.901  b'HP believe        ep                HP an             HP Abacha         #label=0'
# 2 -1.901  b'HP boys           ep                HP father,        HP Juan           #label=0'
# 3 -1.961  b'ep                HP return         HP to             HP Cuba           #label=0'
# 4 -1.986  b'ep                HP a              HP son,           HP Gonzalez       #label=0'
# self-loops:   1.00 * Humza           + -2.70,  5.28 * month.The       +  0.23,  2.13 * CelebrityBirthday.net +  0.64,  1.63 * boothbay        +  0.01,  1.00 * Corp.Semiconductor + -0.96
# fwd 1s:       4.87 * offend          + -0.39,  1.00 * cholo           + -1.21,  5.02 * Grandparents    +  0.99,  4.78 * Gonzalez        + -0.89
# epsilons:                              -0.46,                           -0.58,                           -0.84,                           -1.79
#
# Pattern: 35 of length 5
# Highest scoring spans:
# 0 -1.773  b'HP space          HP will           ep                HP allow          #label=0'
# 1 -1.876  b'HP I              HP can            ep                HP assure         #label=0'
# 2 -1.999  b'HP donor          HP will           ep                HP cost           #label=1'
# 3 -2.005  b'HP bugs           HP are            ep                HP not            #label=0'
# 4 -2.026  b'HP identical      HP to             ep                HP those          #label=0'
# self-loops:   1.00 * TS.Mercury      + -1.42,  1.00 * P-18            +  0.66,  1.00 * onlyPrice       +  0.15,  1.00 * JenaValve       + -0.10,  1.00 * dailypress.com  + -0.92
# fwd 1s:       4.55 * crewmembers     +  0.62,  3.99 * willl           + -0.35,  3.94 * Performed       + -0.11,  4.45 * slaveholding    +  0.05
# epsilons:                              -1.28,                           -0.59,                           -0.46,                           -0.57
#
# Pattern: 36 of length 5
# Highest scoring spans:
# 0 -1.388  b'ep                HP last           HP week           HP that           #label=1'
# 1 -1.479  b'ep                HP last           HP month          HP that           #label=1'
# 2 -1.568  b'ep                HP Sunday         HP in             HP a              #label=1'
# 3 -1.586  b'ep                HP year           HP in             HP costs,         #label=0'
# 4 -1.613  b'ep                HP quarter        HP a              HP year           #label=1'
# self-loops:   1.00 * TagBermuda      + -0.16,  1.00 * LOTZ            + -3.04,  1.00 * Superfinishing  + -1.24,  1.00 * Desirabl        + -0.87,  1.00 * UnknownCountry  +  0.13
# fwd 1s:       1.28 * Gergel          + -0.39,  5.74 * Feburary        + -0.21,  5.03 * byelections     +  1.02,  5.08 * YEARS           +  0.53
# epsilons:                              -0.35,                           -0.55,                           -1.65,                           -0.61
#
# Pattern: 37 of length 5
# Highest scoring spans:
# 0 -1.307  b'HP day            ep                HP before         HP returning      #label=1'
# 1 -1.393  b'HP last           ep                HP week           HP that           #label=1'
# 2 -1.454  b'HP time           ep                HP four           HP of             #label=0'
# 3 -1.462  b'HP quarter        ep                HP a              HP year           #label=1'
# 4 -1.470  b'HP last           ep                HP month          HP that           #label=1'
# self-loops:   1.00 * 9441            +  0.59,  2.78 * re-opens        +  1.20,  1.00 * glTexImage2D    +  0.13,  1.44 * AvailabilityPrice +  0.51,  1.00 * multi-entry     + -0.56
# fwd 1s:       5.21 * week            + -0.55,  1.00 * ring-buffer     + -0.81,  4.61 * Friday          + -0.32,  4.69 * SPITE           +  0.70
# epsilons:                              -2.16,                           -0.16,                           -0.88,                           -0.87
#
# Pattern: 38 of length 5
# Highest scoring spans:
# 0 -1.138  b'ep                HP trading        ep                HP Friday,        #label=1'
# 1 -1.138  b'ep                HP trading        ep                HP Friday,        #label=1'
# 2 -1.502  b'ep                HP explosives     ep                HP Sunday         #label=1'
# 3 -1.698  b'ep                HP stop           ep                HP Tuesday        #label=1'
# 4 -1.744  b'ep                HP greatgrandfatherep                HP founded        #label=0'
# self-loops:   1.00 * Year-to-Date    +  1.03,  1.00 * articlesnbsp    + -2.21,  5.22 * on              +  0.97,  2.07 * in              +  1.10,  1.00 * carpentry       +  0.68
# fwd 1s:       5.02 * 1CompareNisca   +  1.77,  5.22 * Bourses         + -0.71,  1.29 * 28766           + -0.52,  5.77 * 16:00:52        +  0.57
# epsilons:                              -0.30,                           -0.74,                           -0.42,                           -1.25
#
# Pattern: 39 of length 5
# Highest scoring spans:
# 0 -1.469  b'ep                HP Cuba           ep                HP if             #label=0'
# 1 -1.540  b'ep                HP in             ep                HP force          #label=1'
# 2 -1.572  b'ep                HP war            ep                HP enabled        #label=0'
# 3 -1.573  b'ep                HP female         ep                HP friend         #label=0'
# 4 -1.581  b'ep                HP in             ep                HP neighboring    #label=0'
# self-loops:   1.00 * Kanatzidis      +  0.70,  1.00 * Any             +  0.06,  1.00 * BlackGreen      + -0.54,  1.00 * GARDENS         + -0.23,  1.00 * AptarGroup      + -0.14
# fwd 1s:       1.00 * vingt-et-un     + -0.06,  4.77 * Racial/Ethnic   +  1.76,  1.00 * Sawtooth        + -1.60,  4.40 * path_parts      + -0.42
# epsilons:                              -0.39,                           -1.20,                           -0.30,                           -0.22
#
# Pattern: 40 of length 6
# Highest scoring spans:
# 0 -1.800  b'HP Arabs          HP would          ep                HP have           HP to             #label=0'
# 1 -1.971  b'HP Abacha         HP presidency     ep                HP is             HP a              #label=0'
# 2 -2.066  b'HP police         HP said           ep                HP it             HP did            #label=0'
# 3 -2.068  b'HP Asian          ep                HP economies      HP is             HP also           #label=0'
# 4 -2.105  b'HP force          HP might          ep                HP be             HP extended       #label=1'
# self-loops:   1.00 * HDR-HC1         +  0.73,  1.00 * STOR.E          + -1.29,  1.53 * Glatzel         +  0.61,  4.75 * HOOPER          +  1.55,  1.69 * FriendPrice     + -0.22,  1.00 * SLAZENGER       + -1.71
# fwd 1s:       5.06 * Commanders      +  0.79,  4.68 * Did             +  0.49,  1.00 * Microlipoinjection + -0.58,  4.27 * is              + -0.71,  4.21 * with            + -0.30
# epsilons:                              -1.08,                           -0.43,                           -0.48,                           -0.89,                           -1.59
#
# Pattern: 41 of length 6
# Highest scoring spans:
# 0 -1.400  b'HP later          HP in             HP the            HP day            HP before         #label=1'
# 1 -1.520  b'HP the            HP quarter        HP a              HP year           HP ago,           #label=1'
# 2 -1.553  b'HP Sunday         HP in             HP a              HP shed           HP in             #label=1'
# 3 -1.610  b'HP Thursday       HP in             HP the            HP slaying        HP of             #label=1'
# 4 -1.611  b'HP sales          HP picture        HP this           HP year           HP through        #label=1'
# self-loops:   1.00 * Jewel-Osco      +  1.85,  1.70 * inserting       +  0.39,  1.00 * hatke           + -0.85,  5.26 * SKy             +  1.81,  1.00 * LOTHIAN         +  0.73,  1.00 * 2011,2012       +  1.21
# fwd 1s:       5.20 * week            +  0.02,  5.62 * half-year       +  0.89,  6.25 * a               +  0.97,  6.70 * mid-January     + -0.49,  5.31 * nears           +  0.97
# epsilons:                              -0.83,                           -1.13,                           -0.64,                           -1.29,                           -1.00
#
# Pattern: 42 of length 6
# Highest scoring spans:
# 0 -1.602  b'HP that           ep                HP anyone         HP else           HP was            #label=0'
# 1 -1.615  b'HP also           ep                HP said           HP that           HP the            #label=1'
# 2 -1.703  b'HP to             ep                HP keep           HP Elian          HP in             #label=0'
# 3 -1.721  b'HP dont           ep                HP know           HP what           HP Juan           #label=0'
# 4 -1.762  b'HP many           ep                HP people         HP believe        HP an             #label=0'
# self-loops:   1.00 * GITR            +  1.21,  3.03 * named           +  0.55,  1.00 * Avenged         + -1.34,  1.00 * liquidate       + -1.21,  2.23 * Willits         +  1.22,  1.80 * Flipo           +  0.70
# fwd 1s:       4.22 * are             + -0.73,  5.72 * BMXZnot         +  2.00,  4.76 * neccesary       + -0.87,  4.70 * Goldman         + -0.57,  6.74 * Marischal       +  2.23
# epsilons:                              -1.44,                           -0.16,                           -1.58,                           -1.46,                           -0.34
#
# Pattern: 43 of length 6
# Highest scoring spans:
# 0 -1.073  b'ep                HP the            HP thing          ep                HP very           #label=0'
# 1 -1.111  b'ep                HP the            HP same           ep                HP time           #label=0'
# 2 -1.209  b'ep                HP an             HP everyday       ep                HP matter         #label=0'
# 3 -1.223  b'ep                HP the            HP same           ep                HP message        #label=0'
# 4 -1.275  b'ep                HP is             HP higher         ep                HP than           #label=0'
# self-loops:   1.00 * content!Trade   +  0.81,  1.00 * B10             + -0.00,  4.68 * totalled        +  1.30,  1.00 * Farfus          + -0.89,  1.53 * self.parent     +  0.07,  1.00 * Pattison        + -1.36
# fwd 1s:       1.00 * dmy             + -0.31,  4.47 * is              +  0.05,  4.60 * certian         + -0.87,  1.81 * Writer/Editor   + -0.08,  4.25 * thougth         + -0.31
# epsilons:                              -0.04,                           -0.24,                           -1.15,                           -0.20,                           -0.54
#
# Pattern: 44 of length 6
# Highest scoring spans:
# 0 -2.332  b'HP and            ep                HP out            HP of             HP Iraq           #label=1'
# 1 -2.358  b'HP certain        ep                HP transfers      HP of             HP thrift         #label=0'
# 2 -2.380  b'HP Cuba           ep                HP and            HP wants          HP Elian          #label=0'
# 3 -2.441  b'HP ambassador     ep                HP to             HP the            HP United         #label=0'
# 4 -2.450  b'HP assure         ep                HP you,           HP from           HP what           #label=0'
# self-loops:   1.00 * state-inspected + -0.15,  1.00 * Tamna           + -1.01,  1.57 * 12-01-2005      +  0.88,  1.00 * 14:28:57        +  0.01,  1.76 * shopaholics     +  0.32,  1.00 * Beckett         +  0.13
# fwd 1s:       5.08 * relyable        +  1.37,  1.00 * Bruskewitz      + -1.15,  4.55 * careerIs        +  1.83,  3.82 * Of              +  0.00,  4.87 * Der_K           +  0.05
# epsilons:                              -1.20,                           -0.55,                           -1.53,                           -2.79,                           -0.39
#
# Pattern: 45 of length 6
# Highest scoring spans:
# 0 -2.138  b'HP said           ep                HP Cuban          ep                HP journalist     #label=1'
# 1 -2.214  b'HP said           ep                HP a              ep                HP spokesman      #label=0'
# 2 -2.219  b'HP foreign        ep                HP minister,      ep                HP Janos          #label=1'
# 3 -2.227  b'HP discovered     ep                HP at             ep                HP Rudolphs       #label=0'
# 4 -2.305  b'HP at             ep                HP Andrews        ep                HP Air            #label=0'
# self-loops:   1.00 * Loval           + -0.12,  1.00 * Letoya          + -1.05,  3.93 * knifeScore      +  1.32,  1.00 * davao           + -0.57,  1.00 * taranabant      + -1.66,  4.47 * 14:05:54        +  1.39
# fwd 1s:       5.24 * subsidiary      +  1.70,  1.00 * Tor             + -0.62,  1.00 * Consummate      + -1.62,  5.30 * prochoice       +  0.42,  4.99 * KLM             + -0.86
# epsilons:                              -0.63,                           -0.34,                           -0.73,                           -0.37,                           -0.95
#
# Pattern: 46 of length 6
# Highest scoring spans:
# 0 -2.087  b'ep                HP And            HP the            ep                HP weakness       #label=0'
# 1 -2.133  b'HP wary           HP about          HP the            ep                HP eastward       #label=0'
# 2 -2.252  b'HP directors,     HP aligned        HP with           ep                HP Rallys         #label=0'
# 3 -2.292  b'HP million        HP of             HP that           ep                HP seeped         #label=1'
# 4 -2.341  b'HP higher         HP than           HP the            ep                HP dividend       #label=0'
# self-loops:   1.00 * Herradura       +  0.24,  1.00 * mythology       + -2.13,  1.00 * Dinei           +  0.26,  4.47 * million         +  1.27,  4.63 * Elian           +  0.25,  4.16 * with            +  0.95
# fwd 1s:       4.98 * Humcat          +  1.93,  4.86 * Are             +  0.51,  4.89 * The             +  1.73,  1.00 * Cowbo           + -2.12,  5.85 * Rallys          + -0.77
# epsilons:                              -0.74,                           -0.89,                           -0.50,                           -0.66,                           -0.22
#
# Pattern: 47 of length 6
# Highest scoring spans:
# 0 -2.352  b'ep                HP case           HP of             HP Elian          HP is             #label=1'
# 1 -2.405  b'ep                HP Juan           HP Miguel         HP Gonzalez,      HP was            #label=0'
# 2 -2.410  b'ep                HP in             HP neighboring    HP Tanzania,      HP which          #label=0'
# 3 -2.519  b'ep                HP an             HP Abacha         HP presidency     HP is             #label=0'
# 4 -2.519  b'ep                HP the            HP Asian          HP economies      HP is             #label=0'
# self-loops:   1.00 * Espanhol        + -2.72,  1.00 * CumshotEmbed    +  0.31,  1.00 * Limon           + -0.60,  1.00 * Red-Line        + -0.90,  2.62 * UPCListElement  +  0.50,  1.00 * Archimboldi     + -0.74
# fwd 1s:       1.00 * called-out      + -0.03,  4.80 * accidentals     +  0.16,  5.50 * PubZoneWei      +  0.36,  1.57 * p48.htm         + -1.81,  4.89 * has             + -1.06
# epsilons:                              -0.31,                           -1.49,                           -0.82,                           -1.25,                           -0.57
#
# Pattern: 48 of length 6
# Highest scoring spans:
# 0 -1.586  b'ep                HP last           ep                HP month          HP that           #label=1'
# 1 -1.598  b'ep                HP last           ep                HP week           HP that           #label=1'
# 2 -1.683  b'ep                HP out            ep                HP Friday         HP Oct            #label=1'
# 3 -1.725  b'ep                HP since          ep                HP 1990           HP for            #label=1'
# 4 -1.762  b'ep                HP on             ep                HP Tuesday        HP that           #label=1'
# self-loops:   1.00 * Bismarck        +  0.18,  1.00 * NewsIn          +  0.69,  1.00 * Phalene         + -1.83,  2.86 * 5-0             +  0.80,  1.75 * Starute         +  0.43,  1.00 * Arisawa         +  0.21
# fwd 1s:       1.00 * Llanrumney      + -1.14,  5.26 * last            + -0.13,  1.53 * Thenew          + -0.33,  5.72 * year            + -0.88,  5.00 * Inc.Retrieval   +  0.50
# epsilons:                              -0.30,                           -1.25,                           -0.34,                           -1.88,                           -0.83
#
# Pattern: 49 of length 6
# Highest scoring spans:
# 0 -2.083  b'ep                HP and            ep                HP wants          HP Elian          #label=0'
# 1 -2.191  b'ep                HP to             ep                HP keep           HP Elian          #label=0'
# 2 -2.313  b'ep                HP to             ep                HP return         HP Elian          #label=0'
# 3 -2.353  b'ep                HP said           ep                HP Juan           HP Miguel         #label=0'
# 4 -2.382  b'HP company        HP said           ep                HP it             HP expects        #label=1'
# self-loops:   1.00 * assistsScore    + -1.42,  1.00 * sexualbondage   + -0.44,  1.25 * WindGust24      +  0.85,  1.00 * LogicFAQ        + -1.91,  1.00 * voter-verified  + -0.60,  1.00 * obsolescence    +  0.41
# fwd 1s:       4.17 * SellThe         +  2.28,  4.21 * Jdunham         +  0.57,  1.00 * phc             + -1.31,  4.73 * inherits        + -0.38,  4.49 * Tampabay        +  0.35
# epsilons:                              -0.52,                           -0.42,                           -0.35,                           -1.01,                           -0.59
#
# Pattern: 50 of length 7
# Highest scoring spans:
# 0 -1.774  b'HP into           HP NATO           ep                HP on             ep                HP Friday         #label=1'
# 1 -1.928  b'HP continue       HP through        ep                HP next           ep                HP year           #label=1'
# 2 -1.948  b'HP through        HP a              ep                HP recently       ep                HP announced      #label=1'
# 3 -2.004  b'HP news           HP conference     ep                HP on             ep                HP Tuesday        #label=1'
# 4 -2.016  b'HP in             HP the            ep                HP day            ep                HP before         #label=1'
# self-loops:   1.00 * CarleyCan       +  1.08,  3.23 * Kopps           +  0.71,  1.00 * ru/index        + -0.91,  1.67 * Heathside       +  0.39,  1.00 * 4.2.5           + -1.84,  1.00 * 195/50/15       + -1.31,  1.00 * dealer/distributor +  0.58
# fwd 1s:       6.29 * for             +  0.57,  6.14 * searchesManage  +  0.66,  1.81 * InfoZone        + -0.18,  6.01 * on              + -0.48,  1.00 * Hydrofarm       + -1.80,  6.72 * Januray         + -0.23
# epsilons:                              -1.08,                           -0.47,                           -0.32,                           -0.72,                           -0.65,                           -0.97
#
# Pattern: 51 of length 7
# Highest scoring spans:
# 0 -2.071  b'ep                HP fell           HP 50             ep                HP cents          HP on             #label=1'
# 1 -2.246  b'ep                HP though         HP it             ep                HP were           HP a              #label=0'
# 2 -2.277  b'ep                HP six            HP people         ep                HP were           HP in             #label=1'
# 3 -2.304  b'ep                HP many           HP people         ep                HP believe        HP an             #label=0'
# 4 -2.337  b'ep                HP last           HP month          ep                HP that           HP only           #label=1'
# self-loops:   1.00 * Thracians       +  0.66,  1.00 * montmorency     + -1.62,  1.00 * saids           + -0.84,  3.09 * Program         +  0.55,  1.00 * Haasan          + -1.50,  4.67 * divulge         +  0.41,  1.00 * Lovetone        + -0.32
# fwd 1s:       1.00 * UseLightweightConsBest + -0.22,  5.32 * slid            +  0.57,  4.75 * hasnt           + -0.89,  5.25 * conference      + -0.75,  5.21 * are             + -0.85,  5.22 * a               +  0.23
# epsilons:                              -0.55,                           -1.13,                           -0.94,                           -0.29,                           -0.49,                           -0.38
#
# Pattern: 52 of length 7
# Highest scoring spans:
# 0 -2.813  b'HP fullfledged    HP members        ep                HP of             ep                HP NATO,          #label=1'
# 1 -2.926  b'HP $242           HP million        HP in             HP good           ep                HP will           #label=0'
# 2 -2.985  b'HP a              HP French         ep                HP donor          ep                HP will           #label=1'
# 3 -2.988  b'HP Miami          HP against        ep                HP the            ep                HP repatriation   #label=0'
# 4 -2.998  b'ep                HP with           ep                HP the            ep                HP best           #label=0'
# self-loops:   1.00 * oceanographic   +  0.61,  1.00 * ional           + -0.85,  1.28 * 1950.1          +  0.57,  1.00 * HoistTheColours + -1.41,  2.28 * re-marriage     +  0.92,  1.00 * NN4             + -1.06,  1.00 * Freesat         + -1.47
# fwd 1s:       5.23 * rarement        +  1.80,  4.63 * Gonzalez        +  0.31,  1.00 * 07754           + -0.87,  5.28 * DescriptionOne  +  2.07,  1.00 * Schotty         + -0.19,  4.19 * wavey           + -0.73
# epsilons:                              -0.76,                           -0.72,                           -0.69,                           -0.39,                           -0.30,                           -0.82
#
# Pattern: 53 of length 7
# Highest scoring spans:
# 0 -1.786  b'ep                HP the            ep                HP Cuban          ep                HP exile          #label=0'
# 1 -1.810  b'ep                HP in             ep                HP Cuba           ep                HP and            #label=0'
# 2 -1.875  b'ep                HP of             ep                HP Cuban          ep                HP exiles         #label=0'
# 3 -1.904  b'ep                HP President      ep                HP Fidel          ep                HP Castro         #label=1'
# 4 -1.912  b'ep                HP an             ep                HP Abacha         ep                HP presidency     #label=0'
# self-loops:   1.00 * undergrounding  +  0.62,  4.86 * supercarsthat   +  1.14,  1.00 * Stupidly        + -1.30,  1.31 * co-chairperson  +  0.71,  1.00 * Limo            + -0.07,  1.00 * belanda         + -0.28,  1.00 * Isako           +  0.57
# fwd 1s:       1.00 * shells          + -2.27,  1.00 * Plackemeier     + -1.97,  4.38 * and             +  0.37,  4.72 * Saudi           + -0.36,  1.00 * Ronee           + -0.28,  4.38 * complimented    +  1.45
# epsilons:                              -0.16,                           -0.63,                           -0.07,                           -1.63,                           -0.13,                           -1.31
#
# Pattern: 54 of length 7
# Highest scoring spans:
# 0 -2.459  b'HP Central        ep                HP European       HP leaders        HP who            HP brought        #label=0'
# 1 -2.469  b'HP An             ep                HP elderly        HP Catholic       HP man            HP was            #label=0'
# 2 -2.496  b'HP Czech          ep                HP Republic       HP today          HP became         HP fullfledged    #label=1'
# 3 -2.555  b'HP of             ep                HP NATO           HP meant          HP that           HP Hungary        #label=1'
# 4 -2.567  b'HP the            ep                HP United         HP Nations,       HP is             HP part           #label=0'
# self-loops:   1.00 * offersSave      + -0.42,  1.00 * viewsGood       + -0.49,  1.00 * Assimilation    + -1.02,  2.94 * investigation.The +  1.05,  1.00 * day/time        + -1.07,  1.63 * dollas          +  0.84,  1.00 * Waduh           + -2.69
# fwd 1s:       4.88 * break-adjusted  +  2.33,  1.00 * 1:120           + -2.08,  4.68 * Koreans         + -0.47,  4.54 * are             +  0.50,  4.42 * persons         +  1.08,  4.55 * bequest         +  1.03
# epsilons:                              -1.65,                           -0.36,                           -0.23,                           -0.95,                           -0.58,                           -0.61
#
# Pattern: 55 of length 7
# Highest scoring spans:
# 0 -2.054  b'HP Abacha         ep                HP presidency     ep                HP is             HP a              #label=0'
# 1 -2.208  b'HP Elians         ep                HP father         ep                HP has            HP the            #label=1'
# 2 -2.214  b'HP of             ep                HP Elian          ep                HP is             HP for            #label=1'
# 3 -2.270  b'HP Monetary       ep                HP Fund           ep                HP are            HP not            #label=0'
# 4 -2.275  b'HP Bond           ep                HP Portfolio      ep                HP has            HP seen           #label=1'
# self-loops:   1.00 * OfTag           +  0.57,  1.56 * watts/18        +  0.55,  1.00 * CJJ             +  0.14,  2.65 * Buldings        +  0.79,  5.05 * after           +  0.34,  1.00 * mucking         + -1.70,  1.00 * heureCourt      + -0.72
# fwd 1s:       5.36 * 2011/02/24      +  0.86,  1.00 * transgresseth   + -1.74,  5.18 * priceBreaksMAP  +  0.26,  1.00 * overspreads     + -0.74,  4.97 * are             + -1.03,  6.02 * a               +  1.73
# epsilons:                              -0.78,                           -0.32,                           -1.03,                           -0.19,                           -0.78,                           -1.07
#
# Pattern: 56 of length 7
# Highest scoring spans:
# 0 -2.307  b'ep                HP many           ep                HP Russians       HP and            HP some           #label=0'
# 1 -2.384  b'ep                HP Bond           ep                HP Portfolio      HP has            HP seen           #label=1'
# 2 -2.418  b'ep                HP can            ep                HP compete        HP and            HP become         #label=0'
# 3 -2.447  b'ep                HP These          ep                HP conversations  HP are            HP remembered     #label=0'
# 4 -2.455  b'ep                HP those          ep                HP who            HP were           HP responsible    #label=1'
# self-loops:   1.00 * ISIL            +  0.11,  1.00 * PowerSearch     + -1.10,  1.00 * biceps.Put      +  0.43,  4.33 * phrase          +  1.20,  1.00 * Macfayden       + -1.29,  1.00 * Maraviroc       +  0.02,  1.00 * .5:30           + -1.26
# fwd 1s:       1.00 * Erycina         + -1.62,  4.37 * tend            +  0.02,  1.25 * E20-455         + -0.11,  1.00 * Technoclub      + -1.11,  4.15 * and             +  0.58,  4.10 * characters      +  0.59
# epsilons:                              -0.28,                           -0.45,                           -0.24,                           -0.50,                           -1.35,                           -0.73
#
# Pattern: 57 of length 7
# Highest scoring spans:
# 0 -1.947  b'HP of             ep                HP Elian          ep                HP is             HP for            #label=1'
# 1 -2.049  b'HP believe        ep                HP Kopp           ep                HP was            HP driven         #label=0'
# 2 -2.149  b'HP Bond           ep                HP Portfolio      ep                HP has            HP seen           #label=1'
# 3 -2.163  b'HP circles,       ep                HP Kopp           ep                HP had            HP been           #label=1'
# 4 -2.183  b'HP keep           ep                HP Elian          ep                HP in             HP this           #label=0'
# self-loops:   1.00 * Monsanto        + -1.37,  1.00 * approximate     +  0.37,  1.00 * Plug            +  0.48,  1.00 * Ford/New        +  0.54,  1.00 * casualty        +  0.64,  1.00 * detailsReturns  + -0.88,  1.00 * Muslim          +  0.68
# fwd 1s:       4.90 * 62.50           +  1.98,  1.72 * calculationscredit +  0.74,  5.13 * Thigpen         + -0.30,  1.67 * RollingStone.com +  0.31,  5.27 * 33yrs           +  2.03,  5.04 * all             +  2.88
# epsilons:                              -0.96,                           -0.21,                           -1.74,                           -0.32,                           -0.67,                           -0.70
#
# Pattern: 58 of length 7
# Highest scoring spans:
# 0 -2.730  b'HP police         HP said           ep                HP it             ep                HP did            #label=0'
# 1 -2.750  b'HP in             HP preferred      ep                HP stock          ep                HP and            #label=0'
# 2 -2.845  b'HP Juan           HP Miguel         HP Gonzalez,      ep                HP was            HP also           #label=0'
# 3 -2.853  b'HP also           HP said           HP that           HP the            ep                HP price          #label=1'
# 4 -2.865  b'HP Juan           HP Miguel         ep                HP thinks         ep                HP or             #label=0'
# self-loops:   1.00 * sells           + -0.77,  1.00 * O'Neals         + -0.93,  1.00 * MINUTESWHEN     + -0.85,  1.77 * AdCarsFind      +  0.42,  1.00 * Designer/Drafter + -0.29,  1.75 * Shenouda        +  0.24,  1.00 * London/Zone     + -0.32
# fwd 1s:       4.91 * RentOklahoma    +  0.44,  5.07 * Ramirez         +  0.06,  2.92 * 80              + -0.61,  5.07 * Definitely      +  1.42,  1.00 * oefenen         + -2.03,  4.97 * and             + -0.53
# epsilons:                              -1.22,                           -0.76,                           -0.59,                           -0.29,                           -0.66,                           -0.80
#
# Pattern: 59 of length 7
# Highest scoring spans:
# 0 -2.427  b'HP A              HP phony          HP address        ep                HP listed         HP on             #label=1'
# 1 -2.442  b'HP a              HP female         HP friend         ep                HP after          HP the            #label=0'
# 2 -2.467  b'HP He             HP also           HP said           ep                HP that           HP the            #label=1'
# 3 -2.470  b'HP a              HP news           HP conference     ep                HP on             HP Tuesday        #label=1'
# 4 -2.503  b'HP An             HP elderly        HP Catholic       ep                HP man            HP was            #label=0'
# self-loops:   1.00 * Peregrinus      +  0.97,  1.00 * byMark          + -1.22,  2.48 * approaching     +  0.50,  1.00 * Austal          + -0.33,  1.00 * Niobate         + -0.03,  1.00 * pl              +  0.92,  1.00 * SPRG            + -0.46
# fwd 1s:       4.55 * The             +  0.38,  4.59 * victims         + -0.89,  5.01 * sentance        +  1.02,  1.00 * Hwange          + -0.89,  4.79 * are/were        +  0.55,  4.41 * celebrity-studded +  1.67
# epsilons:                              -0.75,                           -1.54,                           -0.26,                           -0.31,                           -1.78,                           -0.24

# %%
interpret_documents(model, 1, test_data, test_text, "data/interpret_best.txt", 20)
# Out:
# MM: 0.002, other: 0.003
# ss torch.Size([1, 60])
# sopa_master/interpret_classification_results.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = softmax(res).data
# sopa_master/interpret_classification_results.py:52: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   forwarded = softmax(model.mlp.forward(Variable(torch.FloatTensor(scores_data)))).data.numpy()
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.007
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.007
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.007
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.15
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.146
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.008
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.007
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.006
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.008
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.001
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.002, other: 0.005
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.002
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.003
# ss torch.Size([1, 60])
# MM: 0.001, other: 0.004
# ss torch.Size([1, 60])
